# %% [markdown]
# # Visualizing

# %%
import pandas as pd
df = pd.read_csv('APawstats.csv')

# %%
df.head()
# Out:
#   trackcode RaceMeet   RaceDate  RaceNumber               Surface RaceType  \
# 0       KEE  Fall 06  10/6/2006           1  Polytrack                 MSW
# 1       KEE  Fall 06  10/6/2006           2  Polytrack                 CLM
# 2       KEE  Fall 06  10/6/2006           3  Polytrack                 CLM
# 3       KEE  Fall 06  10/6/2006           4  Turf                      ALW
# 4       KEE  Fall 06  10/6/2006           5  Polytrack                 MSW
#
#   ExtendedRaceType  Distance temperature RainFall  ... PriorTurfStarts  \
# 0               3U       8.5          74           ...               3
# 1              7.5       6.5          74           ...               6
# 2               50       6.0          74           ...               2
# 3             NW2L       8.5          74           ...               1
# 4              2YO       7.0          74           ...               0
#
#    LastWorkoutLocation  RouteSprint        WinnersSire  \
# ...

# %%
df.describe()
# Out:
#         RaceNumber     Distance    FieldSize  WinningPostPosition  \
# count  4245.000000  4245.000000  4245.000000          4245.000000
# mean      5.250412     7.520495     9.215783             5.101060
# std       2.762889     1.500527     2.150134             2.946013
# min       1.000000     4.500000     3.000000             1.000000
# 25%       3.000000     6.000000     7.000000             3.000000
# 50%       5.000000     7.000000     9.000000             5.000000
# 75%       8.000000     8.500000    11.000000             7.000000
# max      12.000000    20.000000    14.000000            14.000000
#
#               odds  HalfMilePosition  HalfMileTime    FinalTime  \
# count  4245.000000       4245.000000   4245.000000  4245.000000
# mean      6.115948         -2.299205     47.271168    91.253333
# std       7.569693          3.367945      2.834590    20.506552
# min       0.100000        -26.750000      0.000000     0.000000
# ...

# %%
winners = df[df['WinningPostPosition'] == 1]

# %%
winners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 519 entries, 10 to 4208
# Data columns (total 36 columns):
# trackcode               519 non-null object
# RaceMeet                519 non-null object
# RaceDate                519 non-null object
# RaceNumber              519 non-null int64
# Surface                 519 non-null object
# RaceType                519 non-null object
# ExtendedRaceType        519 non-null object
# Distance                519 non-null float64
# temperature             519 non-null object
# RainFall                519 non-null object
# GallopIndicator         519 non-null object
# FieldSize               519 non-null int64
# WinningPostPosition     519 non-null int64
# HorseName               519 non-null object
# odds                    519 non-null float64
# Favorite                519 non-null object
# HalfMilePosition        519 non-null float64
# HalfMileTime            519 non-null float64
# FinalTime               519 non-null float64
# ...

# %%
winners.groupby('WinnersOwner')
